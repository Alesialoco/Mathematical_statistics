# %% [markdown]
# #T8.

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %%
from scipy.stats import chi2
delta = 20.4826
p_value = chi2.sf(delta, 2)
print(f"p-value = {p_value}")
# Out:
# p-value = 3.566645310138641e-05
